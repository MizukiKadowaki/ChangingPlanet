# %%
import os

import pandas as pd
import numpy as np
import re

# %% [markdown]
# Plastic polution in the top 20 rivers 2015

# %%
fp = os.path.join('data', 'plastic-top-20-rivers.csv')
plastic_rivers = pd.read_csv(fp)
plastic_rivers
# Out:
#                                                Entity      Code  Year  \
# 0                                              Africa       NaN  2015
# 1            Amazon (Brazil, Peru, Colombia, Ecuador)       NaN  2015
# 2                                                Asia       NaN  2015
# 3                                   Australia-Pacific       NaN  2015
# 4                                 Brantas (Indonesia)       NaN  2015
# 5                             Central & North America       NaN  2015
# 6                           Cross (Nigeria, Cameroon)       NaN  2015
# 7                                        Dong (China)       NaN  2015
# 8                                              Europe       NaN  2015
# 9                          Ganges (India, Bangladesh)       NaN  2015
# 10                                   Hanjiang (China)       NaN  2015
# 11                                    Huangpu (China)       NaN  2015
# ...

# %% [markdown]
# ## ALPLA Werke Alwin Lehner GMBH & Co KG 2015-2018
# Data from sustainability report 2018
# https://sustainability-report18.alpla.com/en/about-alpla

# %%
alpla = pd.DataFrame(index = ["Revenue", "Employees", "Production plants", "In-house", "Countries"], columns = [2015, 2016, 2017, 2018])
alpla[2015] = [3.3, 16500, 159, 73, 42]
alpla[2016] = [3.25, 18300, 172, 69, 43]
alpla[2017] = [3.4, 19300, 176, 72, 45]
alpla[2018] = [3.66, 20800, 178, 72, 46]
alpla.to_csv("data/alpla_company_stats.csv", index = False)
